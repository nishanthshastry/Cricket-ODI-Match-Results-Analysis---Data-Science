# %%
import pandas as pd
import numpy as np

# %%
#initialise the 'df' variable with the '.csv' file
df = pd.read_csv("ODI_Match_Results.csv")

# %%
#print the first 5 rows
df.head()
# Out:
#    sl_no Result    Margin  BR  Toss  Bat   Opposition     Ground Start Date  \
# 0    418    won   85 runs NaN  lost  1st      v India    Kolkata   3-Jan-13
# 1    692   lost   85 runs NaN   won  2nd   v Pakistan    Kolkata   3-Jan-13
# 2    419   lost   10 runs NaN  lost  2nd      v India      Delhi   6-Jan-13
# 3    693    won   10 runs NaN   won  1st   v Pakistan      Delhi   6-Jan-13
# 4    121   lost  107 runs NaN  lost  2nd  v Australia  Melbourne  11-Jan-13
#
#      Match_ID   Country  Country_ID
# 0  ODI # 3315  Pakistan           7
# 1  ODI # 3315     India           6
# 2  ODI # 3316  Pakistan           7
# 3  ODI # 3316     India           6
# 4  ODI # 3317  SriLanka           8

# %%
#print the first 5 rows
df.tail()
# Out:
#       sl_no Result     Margin   BR  Toss  Bat  Opposition      Ground  \
# 1317    997    won  3 wickets  3.0   won  2nd  v Pakistan  Nottingham
# 1318    282   aban        NaN  NaN   NaN  NaN  v Scotland   Edinburgh
# 1319   1322    NaN        NaN  NaN   won  2nd   v Ireland     Belfast
# 1320    559    NaN        NaN  NaN  lost  2nd   v England       Leeds
# 1321    998    NaN        NaN  NaN   won  1st  v Pakistan       Leeds
#
#      Start Date     Match_ID      Country  Country_ID
# 1317  17-May-19   ODI # 4138      England           1
# 1318  18-May-19  ODI # 4138a     SriLanka           8
# 1319  19-May-19   ODI # 4139  Afghanistan          40
# 1320  19-May-19   ODI # 4140     Pakistan           7
# 1321  19-May-19   ODI # 4140      England           1

# %%
#check for each column the number of NaN's
df.isna().sum()
# Out:
# sl_no           0
# Result          3
# Margin         96
# BR            716
# Toss           26
# Bat            30
# Opposition      0
# Ground          0
# Start Date      0
# Match_ID        0
# Country         0
# Country_ID      0
# dtype: int64

# %%
#to find dimensions of the dataset
df.shape
# Out:
# (1322, 12)

# %%
df.isnull().mean()
# Out:
# sl_no         0.000000
# Result        0.002269
# Margin        0.072617
# BR            0.541604
# Toss          0.019667
# Bat           0.022693
# Opposition    0.000000
# Ground        0.000000
# Start Date    0.000000
# Match_ID      0.000000
# Country       0.000000
# Country_ID    0.000000
# dtype: float64

# %%
df.isnull().mean().sum()
# Out:
# 0.6588502269288956

# %%
df.isna().mean()
# Out:
# sl_no         0.000000
# Result        0.002269
# Margin        0.072617
# BR            0.541604
# Toss          0.019667
# Bat           0.022693
# Opposition    0.000000
# Ground        0.000000
# Start Date    0.000000
# Match_ID      0.000000
# Country       0.000000
# Country_ID    0.000000
# dtype: float64

# %%
df.isna().mean().sum()
# Out:
# 0.6588502269288956

# %%
df.isna().sum()
# Out:
# sl_no           0
# Result          3
# Margin         96
# BR            716
# Toss           26
# Bat            30
# Opposition      0
# Ground          0
# Start Date      0
# Match_ID        0
# Country         0
# Country_ID      0
# dtype: int64

# %%
df.isna().sum().sum()
# Out:
# 871

# %%
df.isnull().sum()
# Out:
# sl_no           0
# Result          3
# Margin         96
# BR            716
# Toss           26
# Bat            30
# Opposition      0
# Ground          0
# Start Date      0
# Match_ID        0
# Country         0
# Country_ID      0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 871

# %%
df.fillna(df.mean())
# Out:
#       sl_no Result     Margin          BR  Toss  Bat      Opposition  \
# 0       418    won    85 runs   51.409241  lost  1st         v India
# 1       692   lost    85 runs   51.409241   won  2nd      v Pakistan
# 2       419   lost    10 runs   51.409241  lost  2nd         v India
# 3       693    won    10 runs   51.409241   won  1st      v Pakistan
# 4       121   lost   107 runs   51.409241  lost  2nd     v Australia
# 5      1096    won   107 runs   51.409241   won  1st     v Sri Lanka
# 6       694   lost     9 runs   51.409241  lost  2nd       v England
# 7       852    won     9 runs   51.409241   won  1st         v India
# 8       122    won  8 wickets   59.000000   won  2nd     v Australia
# 9      1097   lost  8 wickets   59.000000  lost  1st     v Sri Lanka
# 10      695    won   127 runs   51.409241   won  1st       v England
# 11      853   lost   127 runs   51.409241  lost  2nd         v India
# 12      123    won  4 wickets  180.000000  lost  2nd     v Australia
# ...

# %%
df['BR'].isna().sum()
# Out:
# 716

# %%
df.head()
# Out:
#    sl_no Result    Margin  BR  Toss  Bat   Opposition     Ground Start Date  \
# 0    418    won   85 runs NaN  lost  1st      v India    Kolkata   3-Jan-13
# 1    692   lost   85 runs NaN   won  2nd   v Pakistan    Kolkata   3-Jan-13
# 2    419   lost   10 runs NaN  lost  2nd      v India      Delhi   6-Jan-13
# 3    693    won   10 runs NaN   won  1st   v Pakistan      Delhi   6-Jan-13
# 4    121   lost  107 runs NaN  lost  2nd  v Australia  Melbourne  11-Jan-13
#
#      Match_ID   Country  Country_ID
# 0  ODI # 3315  Pakistan           7
# 1  ODI # 3315     India           6
# 2  ODI # 3316  Pakistan           7
# 3  ODI # 3316     India           6
# 4  ODI # 3317  SriLanka           8

# %%
df.tail()
# Out:
#       sl_no Result     Margin   BR  Toss  Bat  Opposition      Ground  \
# 1317    997    won  3 wickets  3.0   won  2nd  v Pakistan  Nottingham
# 1318    282   aban        NaN  NaN   NaN  NaN  v Scotland   Edinburgh
# 1319   1322    NaN        NaN  NaN   won  2nd   v Ireland     Belfast
# 1320    559    NaN        NaN  NaN  lost  2nd   v England       Leeds
# 1321    998    NaN        NaN  NaN   won  1st  v Pakistan       Leeds
#
#      Start Date     Match_ID      Country  Country_ID
# 1317  17-May-19   ODI # 4138      England           1
# 1318  18-May-19  ODI # 4138a     SriLanka           8
# 1319  19-May-19   ODI # 4139  Afghanistan          40
# 1320  19-May-19   ODI # 4140     Pakistan           7
# 1321  19-May-19   ODI # 4140      England           1

# %%
df_rem_nan_catego = df.fillna(df.mean())

# %%
df_rem_nan_catego
# Out:
#       sl_no Result     Margin          BR  Toss  Bat      Opposition  \
# 0       418    won    85 runs   51.409241  lost  1st         v India
# 1       692   lost    85 runs   51.409241   won  2nd      v Pakistan
# 2       419   lost    10 runs   51.409241  lost  2nd         v India
# 3       693    won    10 runs   51.409241   won  1st      v Pakistan
# 4       121   lost   107 runs   51.409241  lost  2nd     v Australia
# 5      1096    won   107 runs   51.409241   won  1st     v Sri Lanka
# 6       694   lost     9 runs   51.409241  lost  2nd       v England
# 7       852    won     9 runs   51.409241   won  1st         v India
# 8       122    won  8 wickets   59.000000   won  2nd     v Australia
# 9      1097   lost  8 wickets   59.000000  lost  1st     v Sri Lanka
# 10      695    won   127 runs   51.409241   won  1st       v England
# 11      853   lost   127 runs   51.409241  lost  2nd         v India
# 12      123    won  4 wickets  180.000000  lost  2nd     v Australia
# ...

# %%
df_rem_nan_catego.head()
# Out:
#    sl_no Result    Margin         BR  Toss  Bat   Opposition     Ground  \
# 0    418    won   85 runs  51.409241  lost  1st      v India    Kolkata
# 1    692   lost   85 runs  51.409241   won  2nd   v Pakistan    Kolkata
# 2    419   lost   10 runs  51.409241  lost  2nd      v India      Delhi
# 3    693    won   10 runs  51.409241   won  1st   v Pakistan      Delhi
# 4    121   lost  107 runs  51.409241  lost  2nd  v Australia  Melbourne
#
#   Start Date    Match_ID   Country  Country_ID
# 0   3-Jan-13  ODI # 3315  Pakistan           7
# 1   3-Jan-13  ODI # 3315     India           6
# 2   6-Jan-13  ODI # 3316  Pakistan           7
# 3   6-Jan-13  ODI # 3316     India           6
# 4  11-Jan-13  ODI # 3317  SriLanka           8

# %%
df_rem_nan_catego.tail()
# Out:
#       sl_no Result     Margin         BR  Toss  Bat  Opposition      Ground  \
# 1317    997    won  3 wickets   3.000000   won  2nd  v Pakistan  Nottingham
# 1318    282   aban        NaN  51.409241   NaN  NaN  v Scotland   Edinburgh
# 1319   1322    NaN        NaN  51.409241   won  2nd   v Ireland     Belfast
# 1320    559    NaN        NaN  51.409241  lost  2nd   v England       Leeds
# 1321    998    NaN        NaN  51.409241   won  1st  v Pakistan       Leeds
#
#      Start Date     Match_ID      Country  Country_ID
# 1317  17-May-19   ODI # 4138      England           1
# 1318  18-May-19  ODI # 4138a     SriLanka           8
# 1319  19-May-19   ODI # 4139  Afghanistan          40
# 1320  19-May-19   ODI # 4140     Pakistan           7
# 1321  19-May-19   ODI # 4140      England           1

# %%
df["Result"].fillna( method ='ffill', inplace = True)

# %%
df.head()
# Out:
#    sl_no Result    Margin  BR  Toss  Bat   Opposition     Ground Start Date  \
# 0    418    won   85 runs NaN  lost  1st      v India    Kolkata   3-Jan-13
# 1    692   lost   85 runs NaN   won  2nd   v Pakistan    Kolkata   3-Jan-13
# 2    419   lost   10 runs NaN  lost  2nd      v India      Delhi   6-Jan-13
# 3    693    won   10 runs NaN   won  1st   v Pakistan      Delhi   6-Jan-13
# 4    121   lost  107 runs NaN  lost  2nd  v Australia  Melbourne  11-Jan-13
#
#      Match_ID   Country  Country_ID
# 0  ODI # 3315  Pakistan           7
# 1  ODI # 3315     India           6
# 2  ODI # 3316  Pakistan           7
# 3  ODI # 3316     India           6
# 4  ODI # 3317  SriLanka           8

# %%
df.tail()
# Out:
#       sl_no Result     Margin   BR  Toss  Bat  Opposition      Ground  \
# 1317    997    won  3 wickets  3.0   won  2nd  v Pakistan  Nottingham
# 1318    282   aban        NaN  NaN   NaN  NaN  v Scotland   Edinburgh
# 1319   1322   aban        NaN  NaN   won  2nd   v Ireland     Belfast
# 1320    559   aban        NaN  NaN  lost  2nd   v England       Leeds
# 1321    998   aban        NaN  NaN   won  1st  v Pakistan       Leeds
#
#      Start Date     Match_ID      Country  Country_ID
# 1317  17-May-19   ODI # 4138      England           1
# 1318  18-May-19  ODI # 4138a     SriLanka           8
# 1319  19-May-19   ODI # 4139  Afghanistan          40
# 1320  19-May-19   ODI # 4140     Pakistan           7
# 1321  19-May-19   ODI # 4140      England           1

# %%
df['BR'].fillna(df.mean())
# Out:
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN
# 6         NaN
# 7         NaN
# 8        59.0
# 9        59.0
# 10        NaN
# 11        NaN
# 12      180.0
# 13      180.0
# 14      131.0
# 15      131.0
# 16       26.0
# 17       26.0
# 18        NaN
# 19        NaN
# 20        NaN
# 21        NaN
# 22        NaN
# 23        NaN
# 24       15.0
# 25       15.0
# 26        0.0
# 27        0.0
# 28       16.0
# 29       16.0
#         ...
# 1292      NaN
# 1293      NaN
# 1294      NaN
# 1295      NaN
# 1296      NaN
# 1297     18.0
# 1298      NaN
# 1299     30.0
# 1300     30.0
# 1301      NaN
# 1302      NaN
# 1303      NaN
# 1304      NaN
# 1305      NaN
# 1306     13.0
# 1307      NaN
# 1308      NaN
# 1309     16.0
# 1310     16.0
# 1311     31.0
# 1312     31.0
# 1313     42.0
# 1314      7.0
# 1315      7.0
# 1316      3.0
# 1317      3.0
# 1318      NaN
# 1319      NaN
# 1320      NaN
# 1321      NaN
# ...

# %%
df.head()
# Out:
#    sl_no Result    Margin  BR  Toss  Bat   Opposition     Ground Start Date  \
# 0    418    won   85 runs NaN  lost  1st      v India    Kolkata   3-Jan-13
# 1    692   lost   85 runs NaN   won  2nd   v Pakistan    Kolkata   3-Jan-13
# 2    419   lost   10 runs NaN  lost  2nd      v India      Delhi   6-Jan-13
# 3    693    won   10 runs NaN   won  1st   v Pakistan      Delhi   6-Jan-13
# 4    121   lost  107 runs NaN  lost  2nd  v Australia  Melbourne  11-Jan-13
#
#      Match_ID   Country  Country_ID
# 0  ODI # 3315  Pakistan           7
# 1  ODI # 3315     India           6
# 2  ODI # 3316  Pakistan           7
# 3  ODI # 3316     India           6
# 4  ODI # 3317  SriLanka           8

# %%
df.tail()
# Out:
#       sl_no Result     Margin   BR  Toss  Bat  Opposition      Ground  \
# 1317    997    won  3 wickets  3.0   won  2nd  v Pakistan  Nottingham
# 1318    282   aban        NaN  NaN   NaN  NaN  v Scotland   Edinburgh
# 1319   1322   aban        NaN  NaN   won  2nd   v Ireland     Belfast
# 1320    559   aban        NaN  NaN  lost  2nd   v England       Leeds
# 1321    998   aban        NaN  NaN   won  1st  v Pakistan       Leeds
#
#      Start Date     Match_ID      Country  Country_ID
# 1317  17-May-19   ODI # 4138      England           1
# 1318  18-May-19  ODI # 4138a     SriLanka           8
# 1319  19-May-19   ODI # 4139  Afghanistan          40
# 1320  19-May-19   ODI # 4140     Pakistan           7
# 1321  19-May-19   ODI # 4140      England           1

# %%
df.fillna(df.mean())
# Out:
#       sl_no Result     Margin          BR  Toss  Bat      Opposition  \
# 0       418    won    85 runs   51.409241  lost  1st         v India
# 1       692   lost    85 runs   51.409241   won  2nd      v Pakistan
# 2       419   lost    10 runs   51.409241  lost  2nd         v India
# 3       693    won    10 runs   51.409241   won  1st      v Pakistan
# 4       121   lost   107 runs   51.409241  lost  2nd     v Australia
# 5      1096    won   107 runs   51.409241   won  1st     v Sri Lanka
# 6       694   lost     9 runs   51.409241  lost  2nd       v England
# 7       852    won     9 runs   51.409241   won  1st         v India
# 8       122    won  8 wickets   59.000000   won  2nd     v Australia
# 9      1097   lost  8 wickets   59.000000  lost  1st     v Sri Lanka
# 10      695    won   127 runs   51.409241   won  1st       v England
# 11      853   lost   127 runs   51.409241  lost  2nd         v India
# 12      123    won  4 wickets  180.000000  lost  2nd     v Australia
# ...

# %%
df['BR'].fillna(df['BR'].mean())
# Out:
# 0        51.409241
# 1        51.409241
# 2        51.409241
# 3        51.409241
# 4        51.409241
# 5        51.409241
# 6        51.409241
# 7        51.409241
# 8        59.000000
# 9        59.000000
# 10       51.409241
# 11       51.409241
# 12      180.000000
# 13      180.000000
# 14      131.000000
# 15      131.000000
# 16       26.000000
# 17       26.000000
# 18       51.409241
# 19       51.409241
# 20       51.409241
# 21       51.409241
# 22       51.409241
# 23       51.409241
# 24       15.000000
# 25       15.000000
# 26        0.000000
# 27        0.000000
# 28       16.000000
# 29       16.000000
#            ...
# 1292     51.409241
# 1293     51.409241
# 1294     51.409241
# 1295     51.409241
# 1296     51.409241
# 1297     18.000000
# 1298     51.409241
# 1299     30.000000
# 1300     30.000000
# 1301     51.409241
# 1302     51.409241
# 1303     51.409241
# 1304     51.409241
# 1305     51.409241
# 1306     13.000000
# 1307     51.409241
# ...

# %%
df.head()
# Out:
#    sl_no Result    Margin  BR  Toss  Bat   Opposition     Ground Start Date  \
# 0    418    won   85 runs NaN  lost  1st      v India    Kolkata   3-Jan-13
# 1    692   lost   85 runs NaN   won  2nd   v Pakistan    Kolkata   3-Jan-13
# 2    419   lost   10 runs NaN  lost  2nd      v India      Delhi   6-Jan-13
# 3    693    won   10 runs NaN   won  1st   v Pakistan      Delhi   6-Jan-13
# 4    121   lost  107 runs NaN  lost  2nd  v Australia  Melbourne  11-Jan-13
#
#      Match_ID   Country  Country_ID
# 0  ODI # 3315  Pakistan           7
# 1  ODI # 3315     India           6
# 2  ODI # 3316  Pakistan           7
# 3  ODI # 3316     India           6
# 4  ODI # 3317  SriLanka           8

# %%
df['BR'].fillna(df['BR'].mean(), inplace = True)

# %%
df.head()
# Out:
#    sl_no Result    Margin         BR  Toss  Bat   Opposition     Ground  \
# 0    418    won   85 runs  51.409241  lost  1st      v India    Kolkata
# 1    692   lost   85 runs  51.409241   won  2nd   v Pakistan    Kolkata
# 2    419   lost   10 runs  51.409241  lost  2nd      v India      Delhi
# 3    693    won   10 runs  51.409241   won  1st   v Pakistan      Delhi
# 4    121   lost  107 runs  51.409241  lost  2nd  v Australia  Melbourne
#
#   Start Date    Match_ID   Country  Country_ID
# 0   3-Jan-13  ODI # 3315  Pakistan           7
# 1   3-Jan-13  ODI # 3315     India           6
# 2   6-Jan-13  ODI # 3316  Pakistan           7
# 3   6-Jan-13  ODI # 3316     India           6
# 4  11-Jan-13  ODI # 3317  SriLanka           8

# %%
df["Margin"].fillna( method ='ffill', inplace = True)

# %%
df["Toss"].fillna( method ='ffill', inplace = True)

# %%
df["Bat"].fillna( method ='ffill', inplace = True)

# %%
df.tail()
# Out:
#       sl_no Result     Margin         BR  Toss  Bat  Opposition      Ground  \
# 1317    997    won  3 wickets   3.000000   won  2nd  v Pakistan  Nottingham
# 1318    282   aban  3 wickets  51.409241   won  2nd  v Scotland   Edinburgh
# 1319   1322   aban  3 wickets  51.409241   won  2nd   v Ireland     Belfast
# 1320    559   aban  3 wickets  51.409241  lost  2nd   v England       Leeds
# 1321    998   aban  3 wickets  51.409241   won  1st  v Pakistan       Leeds
#
#      Start Date     Match_ID      Country  Country_ID
# 1317  17-May-19   ODI # 4138      England           1
# 1318  18-May-19  ODI # 4138a     SriLanka           8
# 1319  19-May-19   ODI # 4139  Afghanistan          40
# 1320  19-May-19   ODI # 4140     Pakistan           7
# 1321  19-May-19   ODI # 4140      England           1

# %%
df.head()
# Out:
#    sl_no Result    Margin         BR  Toss  Bat   Opposition     Ground  \
# 0    418    won   85 runs  51.409241  lost  1st      v India    Kolkata
# 1    692   lost   85 runs  51.409241   won  2nd   v Pakistan    Kolkata
# 2    419   lost   10 runs  51.409241  lost  2nd      v India      Delhi
# 3    693    won   10 runs  51.409241   won  1st   v Pakistan      Delhi
# 4    121   lost  107 runs  51.409241  lost  2nd  v Australia  Melbourne
#
#   Start Date    Match_ID   Country  Country_ID
# 0   3-Jan-13  ODI # 3315  Pakistan           7
# 1   3-Jan-13  ODI # 3315     India           6
# 2   6-Jan-13  ODI # 3316  Pakistan           7
# 3   6-Jan-13  ODI # 3316     India           6
# 4  11-Jan-13  ODI # 3317  SriLanka           8

# %%
df
# Out:
#       sl_no Result     Margin          BR  Toss  Bat      Opposition  \
# 0       418    won    85 runs   51.409241  lost  1st         v India
# 1       692   lost    85 runs   51.409241   won  2nd      v Pakistan
# 2       419   lost    10 runs   51.409241  lost  2nd         v India
# 3       693    won    10 runs   51.409241   won  1st      v Pakistan
# 4       121   lost   107 runs   51.409241  lost  2nd     v Australia
# 5      1096    won   107 runs   51.409241   won  1st     v Sri Lanka
# 6       694   lost     9 runs   51.409241  lost  2nd       v England
# 7       852    won     9 runs   51.409241   won  1st         v India
# 8       122    won  8 wickets   59.000000   won  2nd     v Australia
# 9      1097   lost  8 wickets   59.000000  lost  1st     v Sri Lanka
# 10      695    won   127 runs   51.409241   won  1st       v England
# 11      853   lost   127 runs   51.409241  lost  2nd         v India
# 12      123    won  4 wickets  180.000000  lost  2nd     v Australia
# ...

# %%
df.isna().sum()
# Out:
# sl_no         0
# Result        0
# Margin        0
# BR            0
# Toss          0
# Bat           0
# Opposition    0
# Ground        0
# Start Date    0
# Match_ID      0
# Country       0
# Country_ID    0
# dtype: int64

# %%
df.isna().sum().sum()
# Out:
# 0

# %%
df.to_csv('ODI_Match_Results_cleaned.csv')

# %%
df_cleaned = pd.read_csv('ODI_Match_Results_cleaned.csv')

# %%
df = pd.read_csv('ODI_Match_Results.csv')

# %%
df.head()
# Out:
#    sl_no Result    Margin  BR  Toss  Bat   Opposition     Ground Start Date  \
# 0    418    won   85 runs NaN  lost  1st      v India    Kolkata   3-Jan-13
# 1    692   lost   85 runs NaN   won  2nd   v Pakistan    Kolkata   3-Jan-13
# 2    419   lost   10 runs NaN  lost  2nd      v India      Delhi   6-Jan-13
# 3    693    won   10 runs NaN   won  1st   v Pakistan      Delhi   6-Jan-13
# 4    121   lost  107 runs NaN  lost  2nd  v Australia  Melbourne  11-Jan-13
#
#      Match_ID   Country  Country_ID
# 0  ODI # 3315  Pakistan           7
# 1  ODI # 3315     India           6
# 2  ODI # 3316  Pakistan           7
# 3  ODI # 3316     India           6
# 4  ODI # 3317  SriLanka           8

# %%
df.tail()
# Out:
#       sl_no Result     Margin   BR  Toss  Bat  Opposition      Ground  \
# 1317    997    won  3 wickets  3.0   won  2nd  v Pakistan  Nottingham
# 1318    282   aban        NaN  NaN   NaN  NaN  v Scotland   Edinburgh
# 1319   1322    NaN        NaN  NaN   won  2nd   v Ireland     Belfast
# 1320    559    NaN        NaN  NaN  lost  2nd   v England       Leeds
# 1321    998    NaN        NaN  NaN   won  1st  v Pakistan       Leeds
#
#      Start Date     Match_ID      Country  Country_ID
# 1317  17-May-19   ODI # 4138      England           1
# 1318  18-May-19  ODI # 4138a     SriLanka           8
# 1319  19-May-19   ODI # 4139  Afghanistan          40
# 1320  19-May-19   ODI # 4140     Pakistan           7
# 1321  19-May-19   ODI # 4140      England           1

# %%
df_cleaned.head()
# Out:
#    Unnamed: 0  sl_no Result    Margin         BR  Toss  Bat   Opposition  \
# 0           0    418    won   85 runs  51.409241  lost  1st      v India
# 1           1    692   lost   85 runs  51.409241   won  2nd   v Pakistan
# 2           2    419   lost   10 runs  51.409241  lost  2nd      v India
# 3           3    693    won   10 runs  51.409241   won  1st   v Pakistan
# 4           4    121   lost  107 runs  51.409241  lost  2nd  v Australia
#
#       Ground Start Date    Match_ID   Country  Country_ID
# 0    Kolkata   3-Jan-13  ODI # 3315  Pakistan           7
# 1    Kolkata   3-Jan-13  ODI # 3315     India           6
# 2      Delhi   6-Jan-13  ODI # 3316  Pakistan           7
# 3      Delhi   6-Jan-13  ODI # 3316     India           6
# 4  Melbourne  11-Jan-13  ODI # 3317  SriLanka           8

# %%
df_cleaned.isna().sum().sum()
# Out:
# 0

# %%
df_cleaned.isna().sum().mean()
# Out:
# 67.0

# %%
df_cleaned.tail()
# Out:
#       Unnamed: 0  sl_no Result     Margin         BR  Toss  Bat  Opposition  \
# 1317        1317    997    won  3 wickets   3.000000   won  2nd  v Pakistan
# 1318        1318    282   aban  3 wickets  51.409241   won  2nd  v Scotland
# 1319        1319   1322   aban  3 wickets  51.409241   won  2nd   v Ireland
# 1320        1320    559   aban  3 wickets  51.409241  lost  2nd   v England
# 1321        1321    998   aban  3 wickets  51.409241   won  1st  v Pakistan
#
#           Ground Start Date     Match_ID      Country  Country_ID
# 1317  Nottingham  17-May-19   ODI # 4138      England           1
# 1318   Edinburgh  18-May-19  ODI # 4138a     SriLanka           8
# 1319     Belfast  19-May-19   ODI # 4139  Afghanistan          40
# 1320       Leeds  19-May-19   ODI # 4140     Pakistan           7
# 1321       Leeds  19-May-19   ODI # 4140      England           1

# %%
df_cleaned
# Out:
#       Unnamed: 0  sl_no Result     Margin          BR  Toss  Bat  \
# 0              0    418    won    85 runs   51.409241  lost  1st
# 1              1    692   lost    85 runs   51.409241   won  2nd
# 2              2    419   lost    10 runs   51.409241  lost  2nd
# 3              3    693    won    10 runs   51.409241   won  1st
# 4              4    121   lost   107 runs   51.409241  lost  2nd
# 5              5   1096    won   107 runs   51.409241   won  1st
# 6              6    694   lost     9 runs   51.409241  lost  2nd
# 7              7    852    won     9 runs   51.409241   won  1st
# 8              8    122    won  8 wickets   59.000000   won  2nd
# 9              9   1097   lost  8 wickets   59.000000  lost  1st
# 10            10    695    won   127 runs   51.409241   won  1st
# 11            11    853   lost   127 runs   51.409241  lost  2nd
# 12            12    123    won  4 wickets  180.000000  lost  2nd
# ...

# %%
from sklearn import preprocessing

# %%
x_array = np.array(df_cleaned['BR'])

# %%
x_array
# Out:
# array([51.40924092, 51.40924092, 51.40924092, ..., 51.40924092,
#        51.40924092, 51.40924092])

# %%
normalized_X = preprocessing.normalize([x_array])

# %%
normalized_X
# Out:
# array([[0.02215158, 0.02215158, 0.02215158, ..., 0.02215158, 0.02215158,
#         0.02215158]])

# %%
df_cleaned.head()
# Out:
#    Unnamed: 0  sl_no Result    Margin         BR  Toss  Bat   Opposition  \
# 0           0    418    won   85 runs  51.409241  lost  1st      v India
# 1           1    692   lost   85 runs  51.409241   won  2nd   v Pakistan
# 2           2    419   lost   10 runs  51.409241  lost  2nd      v India
# 3           3    693    won   10 runs  51.409241   won  1st   v Pakistan
# 4           4    121   lost  107 runs  51.409241  lost  2nd  v Australia
#
#       Ground Start Date    Match_ID   Country  Country_ID
# 0    Kolkata   3-Jan-13  ODI # 3315  Pakistan           7
# 1    Kolkata   3-Jan-13  ODI # 3315     India           6
# 2      Delhi   6-Jan-13  ODI # 3316  Pakistan           7
# 3      Delhi   6-Jan-13  ODI # 3316     India           6
# 4  Melbourne  11-Jan-13  ODI # 3317  SriLanka           8

# %%
df_cleaned.to_csv('ODI_Results_normalized.csv')

# %%
df_norm = pd.read_csv('ODI_Results_normalized.csv')

# %%
df_norm.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  sl_no Result    Margin         BR  Toss  Bat  \
# 0           0             0    418    won   85 runs  51.409241  lost  1st
# 1           1             1    692   lost   85 runs  51.409241   won  2nd
# 2           2             2    419   lost   10 runs  51.409241  lost  2nd
# 3           3             3    693    won   10 runs  51.409241   won  1st
# 4           4             4    121   lost  107 runs  51.409241  lost  2nd
#
#     Opposition     Ground Start Date    Match_ID   Country  Country_ID
# 0      v India    Kolkata   3-Jan-13  ODI # 3315  Pakistan           7
# 1   v Pakistan    Kolkata   3-Jan-13  ODI # 3315     India           6
# 2      v India      Delhi   6-Jan-13  ODI # 3316  Pakistan           7
# 3   v Pakistan      Delhi   6-Jan-13  ODI # 3316     India           6
# 4  v Australia  Melbourne  11-Jan-13  ODI # 3317  SriLanka           8

# %%
a = np.array(df_norm['BR'])

# %%
a
# Out:
# array([51.40924092, 51.40924092, 51.40924092, ..., 51.40924092,
#        51.40924092, 51.40924092])

# %%
    for j in normalized_X:
        df_norm['BR'] = j

# %%
df_norm.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  sl_no Result    Margin        BR  Toss  Bat  \
# 0           0             0    418    won   85 runs  0.022152  lost  1st
# 1           1             1    692   lost   85 runs  0.022152   won  2nd
# 2           2             2    419   lost   10 runs  0.022152  lost  2nd
# 3           3             3    693    won   10 runs  0.022152   won  1st
# 4           4             4    121   lost  107 runs  0.022152  lost  2nd
#
#     Opposition     Ground Start Date    Match_ID   Country  Country_ID
# 0      v India    Kolkata   3-Jan-13  ODI # 3315  Pakistan           7
# 1   v Pakistan    Kolkata   3-Jan-13  ODI # 3315     India           6
# 2      v India      Delhi   6-Jan-13  ODI # 3316  Pakistan           7
# 3   v Pakistan      Delhi   6-Jan-13  ODI # 3316     India           6
# 4  v Australia  Melbourne  11-Jan-13  ODI # 3317  SriLanka           8

# %%
import matplotlib.pyplot as plt


N = 10
bat_2 = (20, 35, 30, 35, 27)
bat_1 = (25, 32, 34, 20, 25)
bat_2Std = (2, 3, 4, 1, 2)
bat_1Std = (3, 5, 2, 3, 3)
ind = np.arange(N)    # the x locations for the groups
width = 0.35       # the width of the bars: can also be len(x) sequence

p1 = plt.bar(ind, bat_2, width, yerr=bat_2Std)
p2 = plt.bar(ind, bat_1, width,
             bottom=bat_1Means, yerr=bat_1Std)

plt.ylabel('Scores')
plt.title('Scores by group and gender')
plt.xticks(ind, ('G1', 'G2', 'G3', 'G4', 'G5'))
plt.yticks(np.arange(0, 81, 10))
plt.legend((p1[0], p2[0]), ('Men', 'Women'))

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Won'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-52-c7ffcda2a53d> in <module>
# ----> 1 b = np.array(df_norm['Won'])
#
# ...

# %%
df_norm
# Out:
#       Unnamed: 0  Unnamed: 0.1  sl_no Result     Margin        BR  Toss  Bat  \
# 0              0             0    418    won    85 runs  0.022152  lost  1st
# 1              1             1    692   lost    85 runs  0.022152   won  2nd
# 2              2             2    419   lost    10 runs  0.022152  lost  2nd
# 3              3             3    693    won    10 runs  0.022152   won  1st
# 4              4             4    121   lost   107 runs  0.022152  lost  2nd
# 5              5             5   1096    won   107 runs  0.022152   won  1st
# 6              6             6    694   lost     9 runs  0.022152  lost  2nd
# 7              7             7    852    won     9 runs  0.022152   won  1st
# 8              8             8    122    won  8 wickets  0.025422   won  2nd
# 9              9             9   1097   lost  8 wickets  0.025422  lost  1st
# 10            10            10    695    won   127 runs  0.022152   won  1st
# ...

# %%
import csv
with open('ODI_Results_normalized.csv','r') as bat2in:
    with open('batting_2.csv','w') as batt_2:
            writer = csv.writer(batt_2)
            for row in csv.reader(bat2in):
                if row[7] == '2nd' and row[3] == 'won':
                    writer.writerow(row)

# %%
d = pd.read_csv('batting_2.csv')

# %%
d.shape
# Out:
# (332, 12)

# %%
d.head()
# Out:
#    sl_no Result     Margin     BR  Toss  Bat      Opposition    Ground  \
# 0    122    won  8 wickets   59.0   won  2nd     v Australia  Adelaide
# 1    123    won  4 wickets  180.0  lost  2nd     v Australia  Brisbane
# 2    696    won  7 wickets  131.0   won  2nd       v England    Ranchi
# 3    560    won  1 wickets   26.0   won  2nd  v South Africa     Paarl
# 4    697    won  5 wickets   15.0   won  2nd       v England    Mohali
#
#   Start Date    Match_ID     Country  Country_ID
# 0  13-Jan-13  ODI # 3319    SriLanka           8
# 1  18-Jan-13  ODI # 3321    SriLanka           8
# 2  19-Jan-13  ODI # 3322       India           6
# 3  19-Jan-13  ODI # 3323  NewZealand           5
# 4  23-Jan-13  ODI # 3327       India           6

# %%
with open('ODI_Results_normalized.csv','r') as bat2in:
    with open('batting_1.csv','w') as batt_2:
            writer = csv.writer(batt_2)
            for row in csv.reader(bat2in):
                if row[7] == '1st' and row[3] == 'won':
                    writer.writerow(row)

# %%
countries = set(df['Country'])

# %%
countries
# Out:
# {'Afghanistan',
#  'Australia',
#  'Bangladesh',
#  'England',
#  'India',
#  'NewZealand',
#  'Pakistan',
#  'SouthAfrica',
#  'SriLanka',
#  'WestIndies'}

# %%
with open("batting_2.csv",'r') as f:
    d1 = csv.reader(f)
    with open("batting_2_won_lost.csv",'r') as l:
        g1 = csv.reader(l)
        for i in countries:
            flag1 = 0
            flag2 = 0
            for j in d1:
                if j[10] == i:
                    flag1 = flag1 + 1
            for k in g1:
                if k[10] == i:
                    flag2 = flag2 + 1
            m = (flag1/flag2) *100
            h.append(m)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-181-c4174f11a298> in <module>
#      12                 if k[10] == i:
#      13                     flag2 = flag2 +1
# ---> 14             m = (flag2/flag1) *100
#      15             h.append(m)
#
# ZeroDivisionError: division by zero

# %%
with open('ODI_Results_normalized.csv','r') as bat2in:
    with open('batting_2_won_lost.csv','w') as batt_2:
            writer = csv.writer(batt_2)
            for row in csv.reader(bat2in):
                if row[7] == '2nd':
                    writer.writerow(row)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-161-d229344ce5aa> in <module>
#       1 with open('ODI_Results_normalized.csv','r') as bat2in:
# ----> 2     with open('batting_2_won_lost.csv','w') as batt_2:
#       3             writer = csv.writer(batt_2)
#       4             for row in csv.reader(bat2in):
#       5                 if row[7] == '2nd':
#
# PermissionError: [Errno 13] Permission denied: 'batting_2_won_lost.csv'

# %%
g = pd.read_csv('batting_2_won_lost.csv')

# %%
g.shape
# Out:
# (644, 12)

# %%
g.head()
# Out:
#    sl_no Result     Margin         BR  Toss  Bat   Opposition     Ground  \
# 0    692   lost    85 runs  51.409241   won  2nd   v Pakistan    Kolkata
# 1    419   lost    10 runs  51.409241  lost  2nd      v India      Delhi
# 2    121   lost   107 runs  51.409241  lost  2nd  v Australia  Melbourne
# 3    694   lost     9 runs  51.409241  lost  2nd    v England     Rajkot
# 4    122    won  8 wickets  59.000000   won  2nd  v Australia   Adelaide
#
#   Start Date    Match_ID   Country  Country_ID
# 0   3-Jan-13  ODI # 3315     India           6
# 1   6-Jan-13  ODI # 3316  Pakistan           7
# 2  11-Jan-13  ODI # 3317  SriLanka           8
# 3  11-Jan-13  ODI # 3318     India           6
# 4  13-Jan-13  ODI # 3319  SriLanka           8

# %%
h = list()

# %%
h
# Out:
# []

# %%
with open("batting_2_won_lost.csv") as f:
    reader = csv.reader(f)
    for row in reader:
        print(row[1])
# Out:
# Result
# lost
# lost
# lost
# lost
# won
# lost
# won
# won
# won
# n/r
# lost
# lost
# won
# won
# won
# won
# lost
# lost
# won
# lost
# won
# won
# won
# won
# won
# won
# won
# lost
# won
# lost
# won
# won
# won
# n/r
# won
# won
# won
# lost
# lost
# lost
# won
# lost
# won
# lost
# won
# n/r
# won
# tied
# won
# lost
# lost
# won
# won
# lost
# won
# won
# lost
# lost
# lost
# lost
# won
# lost
# lost
# tied
# lost
# won
# lost
# won
# won
# lost
# won
# won
# lost
# won
# won
# won
# lost
# n/r
# won
# lost
# won
# won
# lost
# won
# won
# n/r
# lost
# won
# lost
# lost
# lost
# lost
# won
# lost
# lost
# n/r
# lost
# won
# lost
# won
# won
# lost
# won
# lost
# won
# lost
# lost
# n/r
# lost
# won
# lost
# won
# won
# won
# lost
# lost
# lost
# won
# won
# lost
# won
# lost
# lost
# tied
# lost
# won
# lost
# lost
# lost
# won
# won
# lost
# won
# lost
# won
# lost
# lost
# won
# won
# lost
# won
# won
# lost
# won
# won
# won
# lost
# lost
# won
# lost
# won
# won
# lost
# ...

# %%
d
# Out:
#      sl_no Result     Margin          BR  Toss  Bat      Opposition  \
# 0      122    won  8 wickets   59.000000   won  2nd     v Australia
# 1      123    won  4 wickets  180.000000  lost  2nd     v Australia
# 2      696    won  7 wickets  131.000000   won  2nd       v England
# 3      560    won  1 wickets   26.000000   won  2nd  v South Africa
# 4      697    won  5 wickets   15.000000   won  2nd       v England
# 5      285    won  1 wickets    0.000000  lost  2nd   v New Zealand
# 6      856    won  7 wickets   16.000000   won  2nd         v India
# 7     1101    won  9 wickets  244.000000  lost  2nd   v West Indies
# 8     1104    won  5 wickets   31.000000  lost  2nd   v West Indies
# 9      563    won  3 wickets    7.000000   won  2nd       v England
# 10     858    won  8 wickets   14.000000   won  2nd   v New Zealand
# 11     859    won  5 wickets   75.000000   won  2nd   v New Zealand
# 12       7    won  7 wickets    6.000000  lost  2nd      v Zimbabwe
# ...
